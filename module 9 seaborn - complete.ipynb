# %% [markdown]
# # Data Visualization with Seaborn

# %% [markdown]
# Before we start, we need to install seaborn.

# %%
import seaborn as sns
import pandas as pd
import numpy as np
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# %autosave 0
# Out:
# Autosave disabled

# %% [markdown]
# Data from here <href>https://www.kaggle.com/uciml/adult-census-income</href>

# %% [markdown]
# **Adult Census Income**
#
# Predict whether income exceeds $50K/yr based on census data

# %%
df = pd.read_csv('adult.csv')

# %%
len(df)
# Out:
# 32561

# %% [markdown]
# In order to better illustrate some of the plots, let's sample only 500 observations. But you shouldn't do it in the project.

# %%
df=df.sample(500,random_state=1)

# %%
df.head()
# Out:
#        age    workclass  fnlwgt  education  education.num      marital.status  \
# 9646    24      Private  336088    HS-grad              9            Divorced
# 709     34  Federal-gov  190228  Bachelors             13  Married-civ-spouse
# 7385    18      Private  104704    HS-grad              9       Never-married
# 16671   44      Private   36271  Bachelors             13  Married-civ-spouse
# 21932   27      Private  178709    Masters             14       Never-married
#
#               occupation   relationship                race     sex  \
# 9646     Exec-managerial  Not-in-family  Amer-Indian-Eskimo  Female
# 709      Protective-serv        Husband               White    Male
# 7385        Adm-clerical      Own-child               Black    Male
# 16671       Craft-repair        Husband               White    Male
# 21932  Machine-op-inspct  Not-in-family               White  Female
#
#        capital.gain  capital.loss  hours.per.week native.country income
# 9646              0             0              50  United-States  <=50K
# 709               0          1902              48  United-States   >50K
# 7385              0             0              40  United-States  <=50K
# 16671             0             0              40  United-States  <=50K
# 21932             0             0              40  United-States  <=50K

# %%
df.corr()
# Out:
#                      age    fnlwgt  education.num  capital.gain  capital.loss  \
# age             1.000000 -0.044819      -0.003402      0.068986      0.067976
# fnlwgt         -0.044819  1.000000       0.014280     -0.035879     -0.058480
# education.num  -0.003402  0.014280       1.000000      0.128262      0.143796
# capital.gain    0.068986 -0.035879       0.128262      1.000000     -0.026987
# capital.loss    0.067976 -0.058480       0.143796     -0.026987      1.000000
# hours.per.week  0.088779 -0.019102       0.194980      0.023619      0.052463
#
#                 hours.per.week
# age                   0.088779
# fnlwgt               -0.019102
# education.num         0.194980
# capital.gain          0.023619
# capital.loss          0.052463
# hours.per.week        1.000000

# %%
df.describe()
# Out:
#              age         fnlwgt  education.num  capital.gain  capital.loss  \
# count  500.00000     500.000000     500.000000    500.000000    500.000000
# mean    38.67200  189034.854000      10.098000    611.436000     90.550000
# std     14.29269  108084.590346       2.634821   4937.728719    416.323439
# min     17.00000   26358.000000       1.000000      0.000000      0.000000
# 25%     27.00000  113465.500000       9.000000      0.000000      0.000000
# 50%     37.00000  182841.500000      10.000000      0.000000      0.000000
# 75%     48.00000  235214.000000      13.000000      0.000000      0.000000
# max     81.00000  799281.000000      16.000000  99999.000000   2415.000000
#
#        hours.per.week
# count      500.000000
# mean        40.142000
# std         12.744201
# min          1.000000
# 25%         38.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
df.isna().any()
# Out:
# age               False
# workclass         False
# fnlwgt            False
# education         False
# education.num     False
# marital.status    False
# occupation        False
# relationship      False
# race              False
# sex               False
# capital.gain      False
# capital.loss      False
# hours.per.week    False
# native.country    False
# income            False
# dtype: bool

# %% [markdown]
# ### Type of variables

# %% [markdown]
# <ul>
# <li><b>Numeric</b> (e.g., age): a variable with many (sometimes infinite) possible numeric values
# <li><b>Categorical</b> (e.g., sex, race): a variable with a finite set of values. There is no intrinsic order between them (sexes or races cannot be sorted from smaller to larger)
# <li><b>Ordinal</b> (e.g., education.num, income): a variable with a finite set of values that can be sorted.
# </ul>

# %% [markdown]
# ### Discretization

# %% [markdown]
# <p>We can turn a numeric variable into an ordinal one through two functions.</p>
# <p>
# <ul>
# <li>For <b>equal-width binning</b>, use <b>pandas.cut</b>.  All bins will be of the same width.
# <li>For <b>equal-frequency binning</b>, use <b>pandas.qcut</b>.  All bins will (attempt to) have the same number of records.
# </ul>
# </p>

# %% [markdown]
# <b>Example</b>: Discretize <i>age</i> into 5 bins of equal width

# %%
df2 = df.copy()

# %%
df2['discretized_age_EW']=pd.cut(df2.age, 5)
# 分成5份，每份一样的wide

# %%
df2['discretized_age_EW'].unique()
# Out:
# [(16.936, 29.8], (29.8, 42.6], (42.6, 55.4], (68.2, 81.0], (55.4, 68.2]]
# Categories (5, interval[float64]): [(16.936, 29.8] < (29.8, 42.6] < (42.6, 55.4] < (55.4, 68.2] < (68.2, 81.0]]

# %% [markdown]
# <b>Example</b>: Discretize <i>age</i> into 5 bins of equal frequency

# %%
df2['discretized_age_EF']=pd.qcut(df2.age, 5)
# 分成5分，每份一样的frequency， 就是在这个range里面的人一样多
# 只是attemp to， 不一定每个都一样！！！！

# %%
df2['discretized_age_EF'].unique()
# Out:
# [(16.999, 25.0], (32.0, 42.0], (42.0, 51.0], (25.0, 32.0], (51.0, 81.0]]
# Categories (5, interval[float64]): [(16.999, 25.0] < (25.0, 32.0] < (32.0, 42.0] < (42.0, 51.0] < (51.0, 81.0]]

# %% [markdown]
# ### One numeric variable

# %% [markdown]
# - 1,one numerical variable： distlpot
# - 2, one ordinal and categorical variable ：countplot

# %% [markdown]
# **age**

# %%
# numeric data - 一般不用countplot
# use distplot is a better way

# %%
sns.countplot(df.age)
# all the individual person on the x axis so it looks bad 
# not very clear 
# 一般用于categorical data

# %%
sns.countplot(x='age', data=df)
#counts of observations in each categorical bin using bars

# %%
sns.distplot(df.age, bins=4)
# 一般只是numeric data 用distplot-因为是连续的
# distribution plot - use to numeric data- very suitable
# 分成4份，每份的wide一样

# %%
sns.distplot(df.age, bins=20)

# %% [markdown]
# **education**

# %%
# ordinal

# %%
sns.countplot(x='education', data=df)
# suitable to ordinal data & categorical data

# %%
sns.countplot(y='education', data=df)

# %% [markdown]
# **race**

# %%
# categorical variable

# %%
sns.countplot(x='race', data=df)

# %% [markdown]
# **discretized_age_EW, discretized_age_EF**

# %%
# 将age - numeric data convert to ordinal data后可以用countplot

# %%
sns.countplot(x='discretized_age_EW', data=df2)
# 和 distplot(bins =5) 是一个意思,都是分成5份

# %%
sns.countplot(x='discretized_age_EF', data=df2)
# 一样的frequency, 但是不完全不一样！！！！

# %%
df2.groupby('discretized_age_EF').size()
#
# Out:
# discretized_age_EF
# (16.999, 25.0]    112
# (25.0, 32.0]       91
# (32.0, 42.0]      101
# (42.0, 51.0]      102
# (51.0, 81.0]       94
# dtype: int64

# %% [markdown]
# ### One categorical vs one numeric variable

# %% [markdown]
# factorplot - kind(point, bar, strip, box, voilin)

# %% [markdown]
# For each value of "marital.status", display the mean age

# %%
df['marital.status'].unique()
# ms - categorical 
# age - numeric
# Out:
# array(['Divorced', 'Married-civ-spouse', 'Never-married', 'Separated',
#        'Married-spouse-absent', 'Widowed', 'Married-AF-spouse'],
#       dtype=object)

# %%
sns.factorplot(y='marital.status', x='age', data=df,aspect=1)
# default - point 
# size - Height (in inches) of each facet. See also: aspect.
# aspect - 设置x 轴 的长度 Aspect ratio of each facet, so that aspect * size gives the width of each facet in inches.

# %%
sns.factorplot(y='marital.status', data=df, x='age',aspect=2)
# Out:
# /Users/zhujunlan/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
sns.factorplot(y='marital.status', data=df, x='age',\
               aspect=2, kind='point')
# Draw a categorical plot onto a FacetGrid.
# The default plot that is shown is a point plot, but other seaborn categorical \
# plots can be chosen with the kind parameter, including box plots, violin plots, bar plots, or strip plots.

# %%
sns.factorplot(y='marital.status', data=df, x='age',\
               aspect=2, kind='bar')

# %%
sns.factorplot(y='marital.status', data=df, x='age',\
               aspect=2, kind='strip')

# %%
sns.factorplot(y='marital.status', data=df, x='age',\
               aspect=2, kind='box')

# %%
sns.factorplot(y='marital.status', data=df, x='age',\
               aspect=2, kind='violin')
# Out:
# /Users/zhujunlan/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %% [markdown]
# ### Two numeric variables (Regression)

# %% [markdown]
# regplot

# %% [markdown]
# A regression plot. Here there are no two numeric variables that are particularly strongly correlated

# %%
# 一般有strong correlated 的两个data都可以画出一个line regreassion 的直线

# %% [markdown]
# We want to assess whether education.num determines hours.per.week (how many hours per week)

# %%
df.corr()
# Out:
#                      age    fnlwgt  education.num  capital.gain  capital.loss  \
# age             1.000000 -0.044819      -0.003402      0.068986      0.067976
# fnlwgt         -0.044819  1.000000       0.014280     -0.035879     -0.058480
# education.num  -0.003402  0.014280       1.000000      0.128262      0.143796
# capital.gain    0.068986 -0.035879       0.128262      1.000000     -0.026987
# capital.loss    0.067976 -0.058480       0.143796     -0.026987      1.000000
# hours.per.week  0.088779 -0.019102       0.194980      0.023619      0.052463
#
#                 hours.per.week
# age                   0.088779
# fnlwgt               -0.019102
# education.num         0.194980
# capital.gain          0.023619
# capital.loss          0.052463
# hours.per.week        1.000000

# %%
sns.regplot(x='education.num', y='hours.per.week', data=df)

# %%
sns.regplot(x='education.num', y='education.num', data=df)

# %% [markdown]
# ### Two categorical variables vs one numeric variable

# %% [markdown]
# factorplot-box(hue 必须是categorical variable， x, y 一个category，一个numeric( x, y 必须有一个是numeric）)

# %% [markdown]
# Show the mean age by sex and marital status

# %%
sns.factorplot(x='marital.status', y='age',hue='sex', data=df, \
               kind='bar',aspect=3)

# %% [markdown]
# ### Two numeric (age, education.num) and one categorical variables (sex)

# %% [markdown]
# factor-box( hue-categorical data, x,y 都是numeric data)

# %%
sns.factorplot(x='education.num', y='age',hue='sex', data=df,kind='bar',aspect=3)

# %% [markdown]
# ### Two categorical (better if ordinal) variables and one numeric variable

# %% [markdown]
# heatmap(gr.unstack())
#
# education.num &  -  ordinal ???????

# %% [markdown]
# Find average capital gain for age and education.num

# %%
gr = df2.groupby(['education.num','discretized_age_EF'])\
    ['capital.gain'].mean()
# discretized_age_EF- 因为想让每个column都一样！ 没有用EW 
# 两个groupby 就会有stack ,
# 所以下一步先unstack

# %%
sns.heatmap(gr.unstack(),annot=True)
# annot - If True, write the data value in each cell. If an array-like with the same 
#shape as data, then use this to annotate the heatmap instead of the raw data.

# %% [markdown]
# ### Four variables: two numeric and two categorical

# %% [markdown]
# factorplot-box(hue- categorical, col(column)- categorical, x,y 都是numeric）

# %%
df.income.unique() #income 是一个cotegorical varibale
# Out:
# array(['<=50K', '>50K'], dtype=object)

# %%
sns.factorplot(x='education.num',y='age',hue='sex',col='income',\
               data=df,kind='bar',aspect=3)

# %% [markdown]
# ### Four variables: one numeric and three categorical

# %% [markdown]
# factorplot-box(x,y必须有一个是numeric)

# %%
sns.factorplot(x='marital.status',y='age',hue='sex',col='income', data=df,kind='bar',aspect=3)

# %% [markdown]
# ### n numeric variables (Pairplots)

# %% [markdown]
# Plot pairwise relationships in a dataset.

# %%
sns.pairplot(df[['age','education.num','capital.gain']])
